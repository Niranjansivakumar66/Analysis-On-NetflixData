# %%
import pandas as pd

# %%
data=pd.read_csv("8. Netflix Dataset.csv")

# %%
data.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data.size
# Out:
# 85679

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   str
#  1   Category      7789 non-null   str
#  2   Title         7789 non-null   str
#  3   Director      5401 non-null   str
#  4   Cast          7071 non-null   str
#  5   Country       7282 non-null   str
#  6   Release_Date  7779 non-null   str
#  7   Rating        7782 non-null   str
#  8   Duration      7789 non-null   str
#  9   Type          7789 non-null   str
#  10  Description   7789 non-null   str
# dtypes: str(11)
# memory usage: 669.5 KB

# %%
data.dtypes
# Out:
# Show_Id         str
# Category        str
# Title           str
# Director        str
# Cast            str
# Country         str
# Release_Date    str
# Rating          str
# Duration        str
# Type            str
# Description     str
# dtype: object

# %% [markdown]
# 1.We have to check for the duplicates

# %%
data.duplicated().sum()
# Out:
# np.int64(2)

# %%
#If you want to know the duplicated rows
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
#Now we have to remove the duplicated rows before deleting check the shape of the dataframe\
data.shape
# Out:
# (7789, 11)

# %%
data.drop_duplicates(inplace = True)

# %%
data.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
#After deleting two rows from the dataframe it is the shape of the dataframe
data.shape
# Out:
# (7787, 11)

# %%
#Now we have check for the null values in each column
data.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
#By using sum, you can get the total null values in each column
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
#Represent the null values in heatmap
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Q1.For House of cards what is the show id and who is the director of this show

# %%
data.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data[data["Title"].isin(["House of Cards"])][["Director","Show_Id"]]
# Out:
#                                                Director Show_Id
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...   s2833

# %% [markdown]
# Q2.In Which Year TV shows are released

# %%
data.dtypes
# Out:
# Show_Id         str
# Category        str
# Title           str
# Director        str
# Cast            str
# Country         str
# Release_Date    str
# Rating          str
# Duration        str
# Type            str
# Description     str
# dtype: object

# %%
#Now we have to create a new column for date column
data["New_Date"]=pd.to_datetime(data["Release_Date"].str.strip(),errors="coerce")

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data["New_Date"].dt.year.value_counts()
# Out:
# New_Date
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
data["New_Date"].dt.year.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='New_Date'>

# %% [markdown]
# Q3 How many movies and TV Shows are in the dataset

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
#data["Category"].value_counts() for this another way is
data.groupby("Category").Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
#Show this in the bar graph
data["Category"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# Q4.Show all the movies that were released in 2004

# %%
data[(data["Category"]=="Movie") & (data["New_Date"].dt.year==2020)].reset_index(drop=True)
# Out:
#      Show_Id Category                                    Title  \
# 0         s5    Movie                                       21
# 1         s7    Movie                                      122
# 2        s15    Movie                                     3022
# 3        s28    Movie                                   #Alive
# 4        s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 1307   s7761    Movie                                Zaki Chan
# 1308   s7782    Movie                                     Zoom
# 1309   s7783    Movie                                     Zozo
# 1310   s7785    Movie                        Zulu Man in Japan
# 1311   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 0                  Robert Luketic
# 1                 Yasir Al Yasiri
# 2                      John Suits
# 3                          Cho Il
# ...

# %% [markdown]
# Q5.Show only the titles of all the movies that were released in india

# %%
data[(data["Category"]=="Movie") & (data["Country"]=="India")][["Title"]].reset_index(drop=True)
# Out:
#                         Title
# 0                         706
# 1                        1920
# 2                      15-Aug
# 3        ​​Kuch Bheege Alfaaz
# 4                ​Goli Soda 2
# ..                        ...
# 847                      Zero
# 848  Zindagi Na Milegi Dobara
# 849                  Zokkomon
# 850                       Zoo
# 851                    Zubaan
#
# [852 rows x 1 columns]

# %% [markdown]
# Q6 Show Top 10 Directors,who gave the highest number of tvs and shows

# %%
a=pd.DataFrame(data["Director"].value_counts())

# %%
a.head(10)
# Out:
#                         count
# Director
# Raúl Campos, Jan Suter     18
# Marcus Raboy               16
# Jay Karas                  14
# Cathy Garcia-Molina        13
# Youssef Chahine            12
# Martin Scorsese            12
# Jay Chapman                12
# Steven Spielberg           10
# David Dhawan                9
# Kunle Afolayan              8

# %% [markdown]
# Q7.Show all the records where category is movie and type is comedian or country is uk

# %%
data[:6]
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# ...

# %%
data[(data["Category"]=="Movie") & (data["Type"]=="Comedies") | (data["Country"]=="United States")].reset_index(drop=True)
# Out:
#      Show_Id Category                       Title         Director  \
# 0         s4    Movie                           9      Shane Acker
# 1         s5    Movie                          21   Robert Luketic
# 2         s8    Movie                         187   Kevin Reynolds
# 3        s11    Movie                        1922     Zak Hilditch
# 4        s15    Movie                        3022       John Suits
# ...      ...      ...                         ...              ...
# 2573   s7759    Movie  Zack and Miri Make a Porno      Kevin Smith
# 2574   s7772    Movie                        Zion       Floyd Russ
# 2575   s7775    Movie                      Zodiac    David Fincher
# 2576   s7779    Movie                  Zombieland  Ruben Fleischer
# 2577   s7782    Movie                        Zoom     Peter Hewitt
#
#                                                    Cast        Country  \
# 0     Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# ...

# %% [markdown]
# Q8.In how many movies/shows tomcruise was cast

# %%
#The str.contains used for the string column containing multiple elements
data[data["Cast"].str.contains("Tom Cruise")].reset_index(drop=True)
# Out:
#   Show_Id Category     Title              Director  \
# 0   s3861    Movie  Magnolia  Paul Thomas Anderson
# 1   s5071    Movie  Rain Man        Barry Levinson
#
#                                                 Cast        Country  \
# 0  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 1  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#       Release_Date Rating Duration                        Type  \
# 0  January 1, 2020      R  189 min  Dramas, Independent Movies
# 1     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                          Description   New_Date
# 0  Through chance, human action, past history and... 2020-01-01
# 1  A fast-talking yuppie is forced to slow down w... 2019-07-01

# %% [markdown]
# Q9.What are the different ratings defined by the netflix

# %%
data[:3]
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description   New_Date
# 0  In a future where the elite inhabit an island ... 2020-08-14
# ...

# %%
a=pd.DataFrame(data["Rating"].unique())

# %%
a
# Out:
#            0
# 0      TV-MA
# 1          R
# 2      PG-13
# 3      TV-14
# 4      TV-PG
# 5         NR
# 6       TV-G
# 7       TV-Y
# 8        NaN
# 9      TV-Y7
# 10        PG
# 11         G
# 12     NC-17
# 13  TV-Y7-FV
# 14        UR

# %% [markdown]
# Q9.1 How movies got TV-14 rating in canada

# %%
data[(data["Rating"]=="TV-14") & (data["Country"]=="Canada")].shape[0]
# Out:
# 23

# %% [markdown]
# Q9.2 How many TV shows got the R rating after year 2018

# %%
data[(data["Category"]=="TV Show") & (data["New_Date"].dt.year>2018)].shape[0]
# Out:
# 1382

# %% [markdown]
# Q10 What is the maximum duration if the movie/Show

# %%
data[["Minute","Units"]]=data["Duration"].str.split(" ",expand=True)

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data["Minute"].max()
# Out:
# '99'
